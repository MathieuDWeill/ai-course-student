# %% [markdown]
# # Bloc 3.5 — A/B testing
#
# **Decision problem:** how would we test whether acting on a weak signal improves outcomes?
#
# Output: lightweight experiment plan.

# %%
from pathlib import Path
import json
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
ROOT = Path.cwd()
SNAPSHOT = "iot_FR_today_5-y_chatgpt_iphone_meteo.csv"
for candidate in [ROOT, *ROOT.parents]:
    if (candidate / "data" / "snapshots" / SNAPSHOT).exists():
        ROOT = candidate
        break
OUT = ROOT / "outputs"
for d in [OUT / "bloc1", OUT / "bloc2", OUT / "bloc3", OUT / "final_product"]: d.mkdir(parents=True, exist_ok=True)
DATA = ROOT / "data" / "snapshots"
def load_clean_long():
    p=OUT/"bloc1"/"clean_trends_long.csv"
    if p.exists(): return pd.read_csv(p, parse_dates=["date"])
    raw=pd.read_csv(DATA/"iot_FR_today_5-y_chatgpt_iphone_meteo.csv", parse_dates=["date"])
    return raw.melt(id_vars="date", var_name="signal", value_name="interest")
def load_clean_wide():
    p=OUT/"bloc1"/"clean_trends_wide.csv"
    if p.exists(): return pd.read_csv(p, parse_dates=["date"])
    raw=pd.read_csv(DATA/"iot_FR_today_5-y_chatgpt_iphone_meteo.csv", parse_dates=["date"])
    return raw.sort_values("date")

# %%
plan=pd.DataFrame([
{"element":"hypothesis","value":"AI-content timing based on signal shifts improves engagement."},
{"element":"unit","value":"weekly content or campaign slot"},
{"element":"metric","value":"click-through rate or qualified visits"},
{"element":"guardrail","value":"do not reduce conversion quality"},
{"element":"decision_rule","value":"ship if uplift is positive and guardrail is stable"},
])
plan.to_csv(OUT/"bloc3"/"ab_test_plan.csv", index=False)
plan

# %% [markdown]
# ## Exercise
#
# Define one guardrail metric for a product team.
#
# ## Conclusion
#
# Experiments turn recommendations into validated decisions.
