# %% [markdown]
# # Bloc 3.6 — Prioritization and ROI
#
# **Decision problem:** which action is worth doing first?
#
# Output: prioritization table.

# %%
from pathlib import Path
import json
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
ROOT = Path.cwd()
SNAPSHOT = "iot_FR_today_5-y_chatgpt_iphone_meteo.csv"
for candidate in [ROOT, *ROOT.parents]:
    if (candidate / "data" / "snapshots" / SNAPSHOT).exists():
        ROOT = candidate
        break
OUT = ROOT / "outputs"
for d in [OUT / "bloc1", OUT / "bloc2", OUT / "bloc3", OUT / "final_product"]: d.mkdir(parents=True, exist_ok=True)
DATA = ROOT / "data" / "snapshots"
def load_clean_long():
    p=OUT/"bloc1"/"clean_trends_long.csv"
    if p.exists(): return pd.read_csv(p, parse_dates=["date"])
    raw=pd.read_csv(DATA/"iot_FR_today_5-y_chatgpt_iphone_meteo.csv", parse_dates=["date"])
    return raw.melt(id_vars="date", var_name="signal", value_name="interest")
def load_clean_wide():
    p=OUT/"bloc1"/"clean_trends_wide.csv"
    if p.exists(): return pd.read_csv(p, parse_dates=["date"])
    raw=pd.read_csv(DATA/"iot_FR_today_5-y_chatgpt_iphone_meteo.csv", parse_dates=["date"])
    return raw.sort_values("date")

# %%
options=pd.DataFrame([
{"option":"monthly weak-signal review","impact":4,"effort":1,"confidence":4},
{"option":"AI content experiment","impact":3,"effort":2,"confidence":3},
{"option":"full forecasting system","impact":4,"effort":5,"confidence":2},
])
options["score"]=(options["impact"]*options["confidence"])/options["effort"]
options.sort_values("score", ascending=False).to_csv(OUT/"bloc3"/"prioritization_roi.csv", index=False)
options.sort_values("score", ascending=False)

# %% [markdown]
# ## Exercise
#
# Change one score and explain whether the recommendation changes.
#
# ## Conclusion
#
# Prioritization makes trade-offs explicit before resources are committed.
