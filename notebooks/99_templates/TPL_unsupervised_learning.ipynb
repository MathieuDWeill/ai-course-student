# %% [markdown]
# # Unsupervised Learning Template
#
# **Decision problem:** what useful structure can we detect when no labels exist?
#
# Keep this notebook short, reproducible and decision-oriented.

# %% [markdown]
# ## Structure
#
# 1. Question
# 2. Data
# 3. Cleaning
# 4. Baseline / analysis
# 5. Result
# 6. Limits
# 7. Next action

# %%
from pathlib import Path
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme(style="whitegrid")
pd.set_option("display.max_columns", 30)

ROOT = Path.cwd()
LOCAL_DATA = ROOT / "data" / "snapshots"
if not LOCAL_DATA.exists():
    LOCAL_DATA = ROOT.parent / "data" / "snapshots"
print("Data path:", LOCAL_DATA.resolve())

# %%
# TODO: load one public/simple dataset or a course snapshot
# df = pd.read_csv(...)

# %% [markdown]
# ## Deliverable
#
# Publish only when the notebook runs top-to-bottom and explains one useful result.
